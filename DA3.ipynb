# %% [markdown]
# <a href="https://colab.research.google.com/github/MahanSinghRajput/ANN/blob/main/DA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

#---------------------------------------------------------
# use decision tree classifier
marks = [[30],[35],[50],[60],[70]]
result = ["f", "f", "p", "p", "p"]

# create model
model = DecisionTreeClassifier()

# train the model
model.fit(marks, result)

# predict new student marks
pred = model.predict([[43]])

print("Prediction:", pred[0])
#---------------------------------------------------------



#---------------------------------------------------------
#KNN
marks2 = [[30],[35],[50],[60],[70]]
result2 = ["f", "f", "p", "p", "p"]

# create model (k = 3 neighbors)
model2 = KNeighborsClassifier(n_neighbors=3)

# train the model
model2.fit(marks2, result2)

# predict new student marks
pred2 = model2.predict([[43]])

print("Prediction:", pred2[0])
#---------------------------------------------------------



#---------------------------------------------------------
#using naive bayes detect email is spam or not
linkInEmail = [[1],[2],[5],[6],[7]]
spamOrNot = ["not-spam","not-spam","spam","spam","spam"]

# create model
model = GaussianNB()

# train the model
model.fit(linkInEmail, spamOrNot)

# predict for a new email (e.g., 4 links)
pred = model.predict([[4]])

print("Prediction:", pred[0])
#---------------------------------------------------------
# Out:
# Prediction: p
# Prediction: f
# Prediction: spam
