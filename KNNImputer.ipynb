# %% [markdown]
# <a href="https://colab.research.google.com/github/MahanSinghRajput/ANN/blob/main/KNNImputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
import numpy as np

X = np.array([
    [1, 2, np.nan],
    [3, np.nan, 6],
    [7, 6, 9]
])

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

imputer = KNNImputer(n_neighbors=2)
X_imputed_scaled = imputer.fit_transform(X_scaled)

X_imputed = scaler.inverse_transform(X_imputed_scaled)

print(X_imputed_scaled)
# Out:
# [[-1.06904497 -1.          0.        ]
#  [-0.26726124  0.         -1.        ]
#  [ 1.33630621  1.          1.        ]]
