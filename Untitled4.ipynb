# %% [markdown]
# <a href="https://colab.research.google.com/github/MahanSinghRajput/ANN/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#S1. Import Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

#S2. Load dataset directly from URL
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

df = pd.read_csv(url, names = cols)

print("First 5 rows: ")
print(df.head())

#S3. Split feature and target
x = df.drop('class', axis = 1)
y = df['class']

#S4. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    x,y,test_size = 0.2, random_state = 7
)

#S5. Feature scaling (Important for KNN)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#S6. Crewte KNN model
knn = KNeighborsClassifier(n_neighbors = 5)

#S7. Train the model
knn.fit(X_train, y_train)

#S8. Predictions
y_pred = knn.predict(X_test)

#S9. Evaluation
print("\nAccuracy: ", accuracy_score(y_test, y_pred))
print("\nConfussionMatrix: \n", confusion_matrix(y_test, y_pred))
print("\nClassification Report: \n", classification_report(y_test,y_pred))
# Out:
# First 5 rows:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
# Accuracy:  0.8666666666666667
#
# ConfussionMatrix:
#  [[ 6  1  0]
#  [ 0 12  0]
#  [ 0  3  8]]
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      0.86      0.92         7
# Iris-versicolor       0.75      1.00      0.86        12
#  Iris-virginica       1.00      0.73      0.84        11
#
#        accuracy                           0.87        30
#       macro avg       0.92      0.86      0.87        30
#    weighted avg       0.90      0.87      0.87        30
